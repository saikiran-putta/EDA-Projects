# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Dell\\Downloads\\hotel_bookings.csv")

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df[df.duplicated()]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 5       Resort Hotel            0         14               2015
# 22      Resort Hotel            0         72               2015
# 43      Resort Hotel            0         70               2015
# 138     Resort Hotel            1          5               2015
# 200     Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119349    City Hotel            0        186               2017
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
# 119373    City Hotel            0        175               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 5                    July                        27
# 22                   July                        27
# ...

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %% [markdown]
# # DATA CLEANING

# %%
df.drop(columns = ['company', 'agent'], inplace = True)

# %%
df = df[df['adults'] != 0]

# %%
df = df[df['adr'] > 0]

# %%
df['arrival_date'] = df['arrival_date_month'] + " " + df['arrival_date_day_of_month'].astype(str) + " " + df['arrival_date_year'].astype(str)
df['arrival_date'] = pd.to_datetime(df['arrival_date'])
df['arrival_date']
# Out:
# 2        2015-07-01
# 3        2015-07-01
# 4        2015-07-01
# 5        2015-07-01
# 6        2015-07-01
#             ...
# 119385   2017-08-30
# 119386   2017-08-31
# 119387   2017-08-31
# 119388   2017-08-31
# 119389   2017-08-29
# Name: arrival_date, Length: 117182, dtype: datetime64[ns]

# %%
df.drop('arrival_date_week_number', inplace = True, axis = 1)

# %%
df['country'].mode()
# Out:
# 0    PRT
# Name: country, dtype: object

# %%
df.loc[df['country'] == 'PRT', 'country'].count()
# Out:
# 46989

# %%
df['country'].fillna(df['country'].mode()[0], inplace = True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          4
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# ...

# %%
df['children'].median()
# Out:
# 0.0

# %%
df['children'].fillna(df['children'].median(), inplace = True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# ...

# %%
df['total_guests'] = (df['adults'] + df['children'] + df['babies']).astype(int)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
# 5                          1                        0                     2
# 6                          1                        0                     2
#
# ...

# %%
graph = sns.countplot(data = df, x = 'hotel')
graph.set(title = 'Hotel type and Reservation Count')
graph.set_xlabel('Hotel Type')
graph.set_ylabel('Reservation_count')
# Out:
# Text(0, 0.5, 'Reservation_count')

# %%
df['hotel'].value_counts(normalize = True)
# Out:
# City Hotel      0.664565
# Resort Hotel    0.335435
# Name: hotel, dtype: float64

# %%
graph = sns.countplot(data = df, x = 'hotel', hue = 'is_canceled')
graph.set(title = 'Hotel type and No. of Cancellations/ non-cancellations')
graph.set_xlabel('Hotel Type')
graph.set_ylabel('No. of Cancellations/ non-cancellations')
# Out:
# Text(0, 0.5, 'No. of Cancellations/ non-cancellations')

# %%
plt.figure(figsize = (12, 12))
graph = sns.countplot(data = df,x = 'arrival_date_month',
              hue = 'hotel', 
              order = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"])
graph.set(title = 'Hotel type and NO. of arrivals per Month')
graph.set_xlabel('Hotel Type')
graph.set_ylabel('NO. of arrivals per Month')
# Out:
# Text(0, 0.5, 'NO. of arrivals per Month')

# %%
graph = sns.countplot(data = df, x = 'adults', hue = 'hotel')
graph.set(title = 'Number of adults reserving')
graph.set_xlabel('No. of Adults')
graph.set_ylabel('Reservation Count')
# Out:
# Text(0, 0.5, 'Reservation Count')

# %%
graph = sns.countplot(data = df, x = 'children', hue = 'hotel')
graph.set(title = 'Number of families with children reserving')
graph.set_xlabel('No. of Children')
graph.set_ylabel('Reservation Count')
# Out:
# Text(0, 0.5, 'Reservation Count')

# %%
sns.set(rc = {'figure.figsize' : (14, 12)})
fig, ax = plt.subplots()
sns.lineplot(
    df[df['hotel'] == 'City Hotel'].groupby(pd.Grouper(key = 'arrival_date', axis = 0,
                                                                freq = 'M')).sum().reset_index(),
                x = 'arrival_date',
                y = 'total_guests',
                ax = ax
)
sns.lineplot(
    df[df['hotel'] == 'Resort Hotel'].groupby(pd.Grouper(key = 'arrival_date', axis = 0,
                                                                freq = 'M')).sum().reset_index(),
                x = 'arrival_date',
                y = 'total_guests',
                ax = ax
    
)
ax.set(title = 'Number of Guests each Month by Hotel Type')
ax.set_xlabel('Month-Year')
ax.set_ylabel('Total Guest Count')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4772\1708888792.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   freq = 'M')).sum().reset_index(),
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4772\1708888792.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   freq = 'M')).sum().reset_index(),
# Text(0, 0.5, 'Total Guest Count')

# %%
sns.set(rc = {'figure.figsize' : (14, 12)})
fig, ax = plt.subplots()
sns.lineplot(
    df[df['hotel'] == 'City Hotel'].groupby(pd.Grouper(key = 'arrival_date', axis = 0,
                                                                freq = 'M')).sum().reset_index(),
                x = 'arrival_date',
                y = 'required_car_parking_spaces',
                ax = ax
)
sns.lineplot(
    df[df['hotel'] == 'Resort Hotel'].groupby(pd.Grouper(key = 'arrival_date', axis = 0,
                                                                freq = 'M')).sum().reset_index(),
                x = 'arrival_date',
                y = 'required_car_parking_spaces',
                ax = ax
    
)
ax.set(title = 'Monthly required Parking Spaces')
ax.set_xlabel('Month-Year')
ax.set_ylabel('Parking Spaces Requirwd')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4772\2883650213.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   freq = 'M')).sum().reset_index(),
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4772\2883650213.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   freq = 'M')).sum().reset_index(),
# Text(0, 0.5, 'Parking Spaces Requirwd')
