# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Dell\\Downloads\\Pokemon.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df.shape
# Out:
# (800, 13)

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df['HP'] == 1]
# Out:
#        #      Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 316  292  Shedinja    Bug  Ghost    236   1      90       45       30
#
#      Sp. Def  Speed  Generation  Legendary
# 316       30     40           3      False

# %%
df['Legendary'].value_counts()
# Out:
# False    735
# True      65
# Name: Legendary, dtype: int64

# %%
df[df['Attack'] == 190]
# Out:
#        #                 Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 163  150  MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      154      100    130           1       True

# %%
df['Speed'].mode()
# Out:
# 0    50
# Name: Speed, dtype: int64

# %%
df['Total'].max()
# Out:
# 780

# %%
df[df['Total'] == 780]
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      100      154      100    130           1       True
# 164       70      194      120    140           1       True
# 426      100      180      100    115           3       True

# %%
df['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
df1 = df[df['Type 1'] == "Flying"]
# Out:
#        #                     Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 702  641  TornadusIncarnate Forme  Flying     NaN    580  79     115       70
# 703  641    TornadusTherian Forme  Flying     NaN    580  79     100       80
# 790  714                   Noibat  Flying  Dragon    245  40      30       35
# 791  715                  Noivern  Flying  Dragon    535  85      70       80
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 702      125       80    111           5       True
# 703      110       90    121           5       True
# 790       45       40     55           6      False
# 791       97       80    123           6      False

# %%
df1['Sp. Atk'].max()
# Out:
# 125

# %%
df[df["Name"] == 'Jolteon']
# Out:
#        #     Name    Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 146  135  Jolteon  Electric    NaN    525  65      65       60      110
#
#      Sp. Def  Speed  Generation  Legendary
# 146       95    130           1      False

# %%
df_type = df[df["Type 1"] == 'Ground']
df_type
# Out:
#        #                     Name  Type 1    Type 2  Total   HP  Attack  \
# 32    27                Sandshrew  Ground       NaN    300   50      75
# 33    28                Sandslash  Ground       NaN    450   75     100
# 55    50                  Diglett  Ground       NaN    265   10      55
# 56    51                  Dugtrio  Ground       NaN    405   35      80
# 112  104                   Cubone  Ground       NaN    320   50      50
# 113  105                  Marowak  Ground       NaN    425   60      80
# 119  111                  Rhyhorn  Ground      Rock    345   80      85
# 120  112                   Rhydon  Ground      Rock    485  105     130
# 222  207                   Gligar  Ground    Flying    430   65      75
# 250  231                   Phanpy  Ground       NaN    330   90      60
# 251  232                  Donphan  Ground       NaN    500   90     120
# 359  328                 Trapinch  Ground       NaN    290   45     100
# ...

# %%
df_type_gen = df_type[df_type['Generation'] == 1]
df_type_gen
# Out:
#        #       Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 32    27  Sandshrew  Ground    NaN    300   50      75       85       20
# 33    28  Sandslash  Ground    NaN    450   75     100      110       45
# 55    50    Diglett  Ground    NaN    265   10      55       25       35
# 56    51    Dugtrio  Ground    NaN    405   35      80       50       50
# 112  104     Cubone  Ground    NaN    320   50      50       95       40
# 113  105    Marowak  Ground    NaN    425   60      80      110       50
# 119  111    Rhyhorn  Ground   Rock    345   80      85       95       30
# 120  112     Rhydon  Ground   Rock    485  105     130      120       45
#
#      Sp. Def  Speed  Generation  Legendary
# 32        30     40           1      False
# 33        55     65           1      False
# 55        45     95           1      False
# 56        70    120           1      False
# 112       50     35           1      False
# 113       80     45           1      False
# ...

# %%
df_type_gen1_sorted = df_type_gen.sort_values(by = 'Sp. Def', ascending = False)
df_type_gen1_sorted
# Out:
#        #       Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 113  105    Marowak  Ground    NaN    425   60      80      110       50
# 56    51    Dugtrio  Ground    NaN    405   35      80       50       50
# 33    28  Sandslash  Ground    NaN    450   75     100      110       45
# 112  104     Cubone  Ground    NaN    320   50      50       95       40
# 55    50    Diglett  Ground    NaN    265   10      55       25       35
# 120  112     Rhydon  Ground   Rock    485  105     130      120       45
# 32    27  Sandshrew  Ground    NaN    300   50      75       85       20
# 119  111    Rhyhorn  Ground   Rock    345   80      85       95       30
#
#      Sp. Def  Speed  Generation  Legendary
# 113       80     45           1      False
# 56        70    120           1      False
# 33        55     65           1      False
# 112       50     35           1      False
# 55        45     95           1      False
# 120       45     40           1      False
# ...

# %%
df_type_gen1_sorted.head(1)
# Out:
#        #     Name  Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 113  105  Marowak  Ground    NaN    425  60      80      110       50
#
#      Sp. Def  Speed  Generation  Legendary
# 113       80     45           1      False

# %%
sns.boxplot(data = df, x = 'Generation', y = 'HP')
# Out:
# <Axes: xlabel='Generation', ylabel='HP'>

# %%
quantile_97 = df['HP'].quantile(0.97)
quantile_97
# Out:
# 120.08999999999992

# %%
hp_outliers_df = df[df["HP"] > quantile_97]
hp_outliers_df
# Out:
#        #                   Name    Type 1    Type 2  Total   HP  Attack  \
# 45    40             Wigglytuff    Normal     Fairy    435  140      70
# 121  113                Chansey    Normal       NaN    450  250       5
# 142  131                 Lapras     Water       Ice    535  130      85
# 145  134               Vaporeon     Water       NaN    525  130      65
# 155  143                Snorlax    Normal       NaN    540  160     110
# 185  171                Lanturn     Water  Electric    460  125      58
# 217  202              Wobbuffet   Psychic       NaN    405  190      33
# 261  242                Blissey    Normal       NaN    540  255      10
# 313  289                Slaking    Normal       NaN    670  150     160
# 321  297               Hariyama  Fighting       NaN    474  144     120
# 350  320                Wailmer     Water       NaN    400  130      70
# 351  321                Wailord     Water       NaN    500  170      90
# ...

# %%
hp_outliers_id = hp_outliers_df.index.tolist()
hp_outliers_id
# Out:
# [45,
#  121,
#  142,
#  145,
#  155,
#  185,
#  217,
#  261,
#  313,
#  321,
#  350,
#  351,
#  473,
#  495,
#  544,
#  545,
#  655,
#  710,
#  711,
#  712,
#  741,
#  769,
#  792,
#  793]

# %%
df_hp_no_outliers = df.drop(index = hp_outliers_id)
df_hp_no_outliers
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
sns.boxplot(data = df_hp_no_outliers, x = 'Generation', y = 'HP')
# Out:
# <Axes: xlabel='Generation', ylabel='HP'>

# %% [markdown]
# # DESCRIPTION

# %% [markdown]
# 1. FIRSTLY, WE LOADED THE POKEMON DATASET
# 2. THEN, WE WANTED TO PUT A COMPETITION BETWEEN THE POKEMONS FROM A CERTAIN GENERATION(probably we took gen-1)
# 3. HENCE, WE FOUND THE OPPONENT IS A POKEMON CALLED "JOELTON"
# 4. THEREFORE, FROM HERE: 'heloadout.com/pokemon-type-chart' WE FOUND THE WEAKNESS OF JOELTON
# 5. JUST WE WANTED TO PREPARE A POKEMON FROM GEN 1 AS JOELTON IS FROM GEN-1
# 6. HENCE, WE CAN FIND THAT THE WEAKNESS OF JOELTON IS 'GROUND'
# 7. ADDITIONALLY,JOELTON HAS HIGHEST SPL. ATTACK POWER
# 8. THEREFORE, WE NEED TO LOOK OUT FOR A POKEMON WHICH HAS HIGHEST SPL. DEFENCE
# 9. ON ANALAYSING BY USING SOME PROCESSES IN DATA ANALYSIS WE FIND THE PERFECT FIT TO COMPETE AGAINST JOELTON IS 'MAROWAK'
